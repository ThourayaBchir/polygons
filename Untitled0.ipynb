# %% [markdown]
# <a href="https://colab.research.google.com/github/ThourayaBchir/polygons/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="lZnfgdl9Qkts6sp9Yhjs")
project = rf.workspace("class-dataset").project("hotspot111")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# Step 4: Train the YOLO11 Model

# !yolo task=detect mode=train model=yolo11s.pt data=/content/datasets/solar/data.yaml epochs=50 imgsz=640 batch=-1


# !yolo task=detect mode=train model=yolo11s.pt \
     data=/content/datasets/solar/data.yaml epochs=70 imgsz=640 \
     batch=16 lr0=0.003 momentum=0.937 weight_decay=0.0005 optimizer=AdamW patience=20




# !yolo task=detect mode=train model=runs/detect/train/weights/last.pt \
#     data=/content/datasets/solar_data/dataset/data.yaml \
#     epochs=100 imgsz=640 batch=16 \
#     lr0=0.001 momentum=0.92 weight_decay=0.0001 \
#     optimizer=Adam warmup_epochs=3 fl_gamma=1.5 \
#     hsv_h=0.0 hsv_s=0.0 degrees=10 mixup=0.2 \
#     patience=30 device=0
# Out:
# Ultralytics 8.3.80 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=val data=/content/datasets/solar/data.yaml  model=runs/detect/train3/weights/best.pt
# Out:
# Ultralytics 8.3.80 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
# val: Scanning /content/datasets/solar/valid/labels.cache... 435 images, 0 backgrounds, 0 corrupt: 100% 435/435 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50% 14/28 [00:04<00:03,  4.43it/s]Keeping Colab alive...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 28/28 [00:07<00:00,  3.62it/s]
#                    all        435       1851      0.853      0.774      0.838      0.447
# Speed: 1.2ms preprocess, 9.8ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to runs/detect/val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model=runs/detect/train3/weights/best.pt conf=0.25 source=datasets/solar/test/images save=True
# Out:
# Ultralytics 8.3.80 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/194 /content/datasets/solar/test/images/6_jpg.rf.363953030e13484089b40726abb0e519.jpg: 640x640 2 Hotspots, 15.6ms
# image 2/194 /content/datasets/solar/test/images/7_jpg.rf.03ab5a4d4c4cc56c4616e202818395b7.jpg: 640x640 3 Hotspots, 15.6ms
# image 3/194 /content/datasets/solar/test/images/7_jpg.rf.883bee0290395f23305ce09e7670488f.jpg: 640x640 1 Hotspot, 15.6ms
# image 4/194 /content/datasets/solar/test/images/DJI_0007_grande_jpg.rf.7d8ef3ed0cfe2ed13d47ab497492a3a0.jpg: 640x640 4 Hotspots, 15.5ms
# image 5/194 /content/datasets/solar/test/images/FLIR0058_jpg.rf.b1302e44b709827ed853710245fe9259.jpg: 640x640 1 Hotspot, 15.5ms
# image 6/194 /content/datasets/solar/test/images/FLIR0067-20-1-_jpg.rf.3f87ffda190b03410777d33e12cd07a9.jpg: 640x640 3 Hotspots, 15.5ms
# ...

# %%
# !yolo export model=runs/detect/train3/weights/best.pt format=onnx
# Out:
# Ultralytics 8.3.80 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.00GHz)
# YOLO11s summary (fused): 100 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#
# PyTorch: starting from 'runs/detect/train3/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (18.3 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim', 'onnxruntime'] not found, attempting AutoUpdate...
# Keeping Colab alive...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 219.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.9/142.9 kB 226.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 201.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 185.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 204.2 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 7.1s, installed 3 packages: ['onnx>=1.12.0', 'onnxslim', 'onnxruntime']
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Backup best.pt
# !cp runs/detect/train3/weights/best.pt runs/detect/train3/weights/best_backup.pt


# save to drive
# !cp runs/detect/train3/weights/best.pt /content/drive/MyDrive/YOLO_Models/best.pt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# # Fine-Tune with More Epochs

# !yolo task=detect mode=train model=runs/detect/train3/weights/best.pt \
#      data=/content/datasets/solar/data.yaml epochs=40 imgsz=640 \
#      batch=16 lr0=0.001 momentum=0.92 weight_decay=0.0003 optimizer=AdamW
# Out:
# Ultralytics 8.3.80 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
